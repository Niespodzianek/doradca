# %%
import pandas as pd
import yfinance as yf

# %%
dat = yf.Ticker("MSFT")

# %%
dat.history(periods="1mo")
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# <ipython-input-3-2108bb977238> in <module>
# ----> 1 dat.history(periods="1mo")
#
# /var/mobile/Containers/Data/Application/D4BDB51D-B421-4FF7-9F5E-44E7D19F0E0F/Documents/site-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     102
#     103         with IndentationContext():
# --> 104             result = func(*args, **kwargs)
#     105
#     106         logger.debug(f'Exiting {func.__name__}()')
#
# /var/mobile/Containers/Data/Application/D4BDB51D-B421-4FF7-9F5E-44E7D19F0E0F/Documents/site-packages/yfinance/base.py in history(self, *args, **kwargs)
#      78     @utils.log_indent_decorator
#      79     def history(self, *args, **kwargs) -> pd.DataFrame:
# ---> 80         return self._lazy_load_price_history().history(*args, **kwargs)
#      81
#      82     # ------------------------
#
# ...
