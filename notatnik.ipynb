# %%
import pandas as pd
import yfinance as yf

# %%
dat = yf.Ticker("MSFT")

# %%
dat.calendar
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# <ipython-input-3-8ba6d870d0a8> in <module>
# ----> 1 dat.calendar
#
# /var/mobile/Containers/Data/Application/D4BDB51D-B421-4FF7-9F5E-44E7D19F0E0F/Documents/site-packages/yfinance/ticker.py in calendar(self)
#     168         Returns a dictionary of events, earnings, and dividends for the ticker
#     169         """
# --> 170         return self.get_calendar()
#     171
#     172     @property
#
# /var/mobile/Containers/Data/Application/D4BDB51D-B421-4FF7-9F5E-44E7D19F0E0F/Documents/site-packages/yfinance/base.py in get_calendar(self, proxy)
#     175     def get_calendar(self, proxy=None) -> dict:
#     176         self._quote.proxy = proxy or self.proxy
# --> 177         return self._quote.calendar
#     178
#     179     def get_sec_filings(self, proxy=None) -> dict:
#
# ...
